# %% [markdown]
# # Ledger analytics
#
# Analytics derive spend from the canonical ledger. Public account history uses `LedgerEntry`, `LedgerCursor`, and `LedgerPage`; no offset pagination or transaction projection is involved.

# %%
from bursar import LedgerCursor, LedgerEntry, LedgerPage

print(LedgerEntry.__name__, LedgerCursor.__name__, LedgerPage.__name__)
